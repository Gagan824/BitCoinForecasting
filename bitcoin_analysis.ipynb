# %%
import pandas as kunfu
import numpy as dragon
import pylab as p
import matplotlib.pyplot as plot
from collections import Counter
import re

#importing packages for the prediction of time-series data
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf

from sklearn.metrics import mean_squared_error
train = kunfu.read_csv('bitcoin_data.csv')
train['Timestamp'] = kunfu.to_datetime(train['Timestamp'], infer_datetime_format=True)
data = train['Close']
Date1 = train['Timestamp']
train1 = train[['Timestamp','Close']]
# Setting the Date as Index
train2 = train1.set_index('Timestamp')
train2.sort_index(inplace=True)
print (type(train2))
print (train2.head())
plot.plot(train2)
plot.xlabel('Timestamp', fontsize=12)
plot.ylabel('Price in USD', fontsize=12)
plot.title("Closing price distribution of bitcoin", fontsize=15)
plot.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#               Close
# Timestamp
# 2017-01-01   997.75
# 2017-01-02  1012.54
# 2017-01-03  1035.24
# 2017-01-04  1114.92
# 2017-01-05  1004.74

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(x):


    #Determing rolling statistics
    rolmean = x.rolling(window=22,center=False).mean()

    rolstd = x.rolling(window=12,center=False).std()
    
    #Plot rolling statistics:
    orig = plot.plot(x, color='blue',label='Original')
    mean = plot.plot(rolmean, color='red', label='Rolling Mean')
    std = plot.plot(rolstd, color='black', label = 'Rolling Std')
    plot.legend(loc='best')
    plot.title('Rolling Mean & Standard Deviation')
    plot.show(block=False)
    
    #Perform Dickey Fuller test    
    result=adfuller(x)
    print('ADF Stastistic: %f'%result[0])
    print('p-value: %f'%result[1])
    pvalue=result[1]
    for key,value in result[4].items():
         if result[0]>value:
            print("The graph is non stationery")
            break
         else:
            print("The graph is stationery")
            break;
    print('Critical values:')
    for key,value in result[4].items():
        print('\t%s: %.3f ' % (key, value))
        
ts = train2['Close']      
test_stationarity(ts)
# Out:
# ADF Stastistic: -1.209303
# p-value: 0.669581
# The graph is non stationery
# Critical values:
# 	1%: -3.446
# 	5%: -2.868
# 	10%: -2.570

# %%
ts_log = dragon.log(ts)
plot.plot(ts_log,color="green")
plot.show()

test_stationarity(ts_log)
# Out:
# ADF Stastistic: -1.032467
# p-value: 0.741239
# The graph is non stationery
# Critical values:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %%
ts_log_diff = ts_log - ts_log.shift()
plot.plot(ts_log_diff)
plot.show()

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# ADF Stastistic: -21.072460
# p-value: 0.000000
# The graph is stationery
# Critical values:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(ts_log, order=(1,1,0))  
results_ARIMA = model.fit(disp=-1)  
plot.plot(ts_log_diff)
plot.plot(results_ARIMA.fittedvalues, color='red')
plot.title('RSS: %.7f'% sum((results_ARIMA.fittedvalues-ts_log_diff)**2))
plot.show()
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\asus\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
model = ARIMA(ts_log, order=(0,1,1))  
results_MA = model.fit(disp=-1)  
plot.plot(ts_log_diff)
plot.plot(results_MA.fittedvalues, color='red')
plot.title('RSS: %.7f'% sum((results_MA.fittedvalues-ts_log_diff)**2))
plot.show()
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\asus\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(ts_log, order=(2,1,0))  
results_ARIMA = model.fit(disp=-1)  
plot.plot(ts_log_diff)
plot.plot(results_ARIMA.fittedvalues, color='red')
plot.title('RSS: %.7f'% sum((results_ARIMA.fittedvalues-ts_log_diff)**2))
plot.show()
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\asus\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
size = int(len(ts_log)-100)
# Divide into train and test
train_arima, test_arima = ts_log[0:size], ts_log[size:len(ts_log)]
history = [x for x in train_arima]
predictions = list()
originals = list()
error_list = list()

print('Printing Predicted vs Expected Values...')
print('\n')
# We go over each value in the test set and then apply ARIMA model and calculate the predicted value. We have the expected value in the test set therefore we calculate the error between predicted and expected value 
for t in range(len(test_arima)):
    model = ARIMA(history, order=(2, 1, 0))
    model_fit = model.fit(disp=-1)
    
    output = model_fit.forecast()
    
    pred_value = output[0]
    
        
    original_value = test_arima[t]
    history.append(original_value)
    
    pred_value = dragon.exp(pred_value)
    
    
    original_value = dragon.exp(original_value)
    
    # Calculating the error
    error = ((abs(pred_value - original_value)) / original_value) * 100
    error_list.append(error)
    print('predicted = %f,   expected = %f,   error = %f ' % (pred_value, original_value, error), '%')
    
    predictions.append(float(pred_value))
    originals.append(float(original_value))
    
# After iterating over whole test set the overall mean error is calculated.   
print('\n Mean Error in Predicting Test Case Articles : %f ' % (sum(error_list)/float(len(error_list))), '%')
plot.figure(figsize=(8, 6))
test_day = [t
           for t in range(len(test_arima))]
labels={'Orginal','Predicted'}
plot.plot(test_day, predictions, color= 'green')
plot.plot(test_day, originals, color = 'orange')
plot.title('Expected Vs Predicted Views Forecasting')
plot.xlabel('Day')
plot.ylabel('Closing Price')
plot.legend(labels)
plot.show()
# Out:
# Printing Predicted vs Expected Values...
#
#
# predicted = 19107.409450,   expected = 17700.000000,   error = 7.951466  %
# predicted = 17827.761763,   expected = 16466.980000,   error = 8.263700  %
# predicted = 16595.355087,   expected = 15600.010000,   error = 6.380413  %
# predicted = 15713.811256,   expected = 14009.790000,   error = 12.163075  %
# predicted = 14057.570684,   expected = 14619.000000,   error = 3.840408  %
# predicted = 14759.907576,   expected = 14157.870000,   error = 4.252317  %
# predicted = 14245.307261,   expected = 13911.280000,   error = 2.401125  %
# predicted = 14004.699505,   expected = 15764.440000,   error = 11.162721  %
# predicted = 15942.240947,   expected = 15364.930000,   error = 3.757329  %
# predicted = 15456.815559,   expected = 14470.070000,   error = 6.819218  %
# predicted = 14560.443980,   expected = 14340.000000,   error = 1.537266  %
# predicted = 14455.353309,   expected = 12640.000000,   error = 14.361972  %
# predicted = 12680.177263,   expected = 13880.000000,   error = 8.644256  %
# predicted = 14011.968346,   expected = 13443.410000,   error = 4.229272  %
# predicted = 13533.328881,   expected = 14678.940000,   error = 7.804454  %
# predicted = 14791.300753,   expected = 15155.620000,   error = 2.403856  %
# predicted = 15280.274162,   expected = 15143.670000,   error = 0.902055  %
# predicted = 15257.073166,   expected = 16928.000000,   error = 9.870787  %
# predicted = 17071.826068,   expected = 17149.670000,   error = 0.453909  %
# predicted = 17298.634400,   expected = 16124.020000,   error = 7.284873  %
# predicted = 16235.942453,   expected = 14999.990000,   error = 8.239689  %
# predicted = 15092.058918,   expected = 14403.510000,   error = 4.780424  %
# predicted = 14489.849571,   expected = 14890.020000,   error = 2.687508  %
# predicted = 15003.946449,   expected = 13243.830000,   error = 13.290086  %
# predicted = 13315.698222,   expected = 13781.410000,   error = 3.379275  %
# predicted = 13866.633546,   expected = 14197.780000,   error = 2.332382  %
# predicted = 14304.017612,   expected = 13647.990000,   error = 4.806771  %
# predicted = 13738.527101,   expected = 13607.040000,   error = 0.966317  %
# predicted = 13697.510774,   expected = 11386.340000,   error = 20.297750  %
# predicted = 11434.714114,   expected = 11191.350000,   error = 2.174573  %
# predicted = 11230.862458,   expected = 11247.570000,   error = 0.148544  %
# predicted = 11315.417989,   expected = 11552.000000,   error = 2.047974  %
# predicted = 11629.510222,   expected = 12775.990000,   error = 8.973706  %
# predicted = 12885.180287,   expected = 11558.870000,   error = 11.474394  %
# predicted = 11635.737923,   expected = 10808.990000,   error = 7.648707  %
# predicted = 10860.798190,   expected = 10851.820000,   error = 0.082734  %
# predicted = 10916.163476,   expected = 11400.960000,   error = 4.252243  %
# predicted = 11480.048008,   expected = 11155.540000,   error = 2.908940  %
# predicted = 11220.707583,   expected = 11092.950000,   error = 1.151701  %
# predicted = 11160.056896,   expected = 11446.540000,   error = 2.502792  %
# predicted = 11522.285064,   expected = 11685.580000,   error = 1.397405  %
# predicted = 11761.055483,   expected = 11162.620000,   error = 5.361067  %
# predicted = 11223.322088,   expected = 9971.000000,   error = 12.559644  %
# predicted = 10008.807829,   expected = 10149.000000,   error = 1.381340  %
# predicted = 10217.455953,   expected = 8998.990000,   error = 13.540030  %
# predicted = 9032.006831,   expected = 8838.830000,   error = 2.185548  %
# predicted = 8873.095183,   expected = 9225.860000,   error = 3.823652  %
# predicted = 9282.734082,   expected = 8191.000000,   error = 13.328459  %
# predicted = 8223.191928,   expected = 6874.270000,   error = 19.622766  %
# predicted = 6863.619190,   expected = 7737.370000,   error = 11.292607  %
# predicted = 7808.536341,   expected = 7588.010000,   error = 2.906247  %
# predicted = 7617.150361,   expected = 8259.760000,   error = 7.780004  %
# predicted = 8309.721927,   expected = 8693.980000,   error = 4.419818  %
# predicted = 8745.595148,   expected = 8560.000000,   error = 2.168168  %
# predicted = 8602.444450,   expected = 8067.000000,   error = 6.637467  %
# predicted = 8102.302002,   expected = 8899.000000,   error = 8.952669  %
# predicted = 8957.617181,   expected = 8522.990000,   error = 5.099468  %
# predicted = 8563.340584,   expected = 9490.980000,   error = 9.773905  %
# predicted = 9540.479082,   expected = 10018.000000,   error = 4.766629  %
# predicted = 10079.367243,   expected = 10196.000000,   error = 1.143907  %
# predicted = 10256.312872,   expected = 11101.000000,   error = 7.609108  %
# predicted = 11171.707397,   expected = 10421.060000,   error = 7.203177  %
# predicted = 10485.739935,   expected = 11173.000000,   error = 6.151079  %
# predicted = 11227.186819,   expected = 11233.410000,   error = 0.055399  %
# predicted = 11307.174696,   expected = 10449.400000,   error = 8.208842  %
# predicted = 10511.461717,   expected = 9843.340000,   error = 6.787551  %
# predicted = 9891.757536,   expected = 10166.100000,   error = 2.698601  %
# predicted = 10219.348980,   expected = 9689.990000,   error = 5.462947  %
# predicted = 9745.720354,   expected = 9590.040000,   error = 1.623355  %
# predicted = 9638.181575,   expected = 10324.700000,   error = 6.649282  %
# predicted = 10380.013747,   expected = 10566.300000,   error = 1.763023  %
# predicted = 10628.279814,   expected = 10314.900000,   error = 3.038128  %
# predicted = 10372.872295,   expected = 10903.130000,   error = 4.863353  %
# predicted = 10962.326613,   expected = 11029.990000,   error = 0.613449  %
# predicted = 11093.932366,   expected = 11445.000000,   error = 3.067432  %
# predicted = 11510.191558,   expected = 11463.270000,   error = 0.409321  %
# predicted = 11530.614638,   expected = 11419.240000,   error = 0.975324  %
# predicted = 11484.540342,   expected = 10723.760000,   error = 7.094343  %
# predicted = 10784.206877,   expected = 9913.030000,   error = 8.788200  %
# predicted = 9960.163675,   expected = 9285.320000,   error = 7.267856  %
# predicted = 9321.073638,   expected = 9230.000000,   error = 0.986713  %
# predicted = 9270.421373,   expected = 8791.470000,   error = 5.447910  %
# predicted = 8830.103211,   expected = 9535.040000,   error = 7.393118  %
# predicted = 9582.702062,   expected = 9120.750000,   error = 5.064847  %
# predicted = 9176.185410,   expected = 9142.320000,   error = 0.370425  %
# predicted = 9182.363441,   expected = 8196.690000,   error = 12.025262  %
# predicted = 8233.092599,   expected = 8265.050000,   error = 0.386657  %
# predicted = 8287.193216,   expected = 8258.540000,   error = 0.346953  %
# predicted = 8298.842729,   expected = 7860.830000,   error = 5.572093  %
# predicted = 7895.747715,   expected = 8188.240000,   error = 3.572102  %
# predicted = 8219.348759,   expected = 8596.930000,   error = 4.392047  %
# predicted = 8645.169642,   expected = 8904.020000,   error = 2.907118  %
# predicted = 8956.105123,   expected = 8893.790000,   error = 0.700659  %
# predicted = 8942.278205,   expected = 8704.670000,   error = 2.729664  %
# predicted = 8745.429471,   expected = 8920.790000,   error = 1.965751  %
# predicted = 8961.309833,   expected = 8547.000000,   error = 4.847430  %
# predicted = 8590.210681,   expected = 8453.900000,   error = 1.612400  %
# predicted = 8486.825595,   expected = 8149.660000,   error = 4.137174  %
# predicted = 8184.217829,   expected = 7791.700000,   error = 5.037640  %
# predicted = 7818.956806,   expected = 8039.860000,   error = 2.747600  %
#
#  Mean Error in Predicting Test Case Articles : 5.293451  %
